# %%
pip install --upgrade langchain openai
# Out:
# ...
#
# ...

# %%
import os
os.environ["OPENAI_API_KEY"] = "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"

# %%
pip install "unstructured[all-docs]"
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: layoutparser 0.0.1 does not provide the extra 'layoutmodels'
# WARNING: layoutparser 0.0.1 does not provide the extra 'tesseract'

# %%
from langchain.document_loaders import DirectoryLoader

directory = 'C:\\Users\\DELL\\Desktop\\ThinkAI\\Task 1\\documents'

def load_docs(directory):
    loader = DirectoryLoader(directory)
    documents = loader.load()
    return documents

documents = load_docs(directory)
len(documents)
# Out:
# 2

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter
def split_docs(documents, chunk_size=1000, chunk_overlap=20):
    text_splitter = RecursiveCharacterTextSplitter(chunk_size= chunk_size, chunk_overlap=chunk_overlap)
    docs = text_splitter.split_documents(documents)
    return docs

docs = split_docs(documents)
print(len(docs))
# Out:
# 7

# %%
print(docs[0].page_content)
# Out:
# Indore, India |
#
# DIMPLE AGRAWAL agrawaldimple79@gmail.com |
#
# (+91)8989431813
#
# linkedin.com/in/dimpleagrawal |
#
# github.com/dimple-agrawal | twitter.com/diwwwmple
#
# EDUCATION
#
# Medi-Caps University, Indore Bachelor of Technology in Computer Science and Engineering
#
# Acquired Cummins India Scholarship covering the complete undergraduate tuition fee.
#
# Shree Krishna Public School, Indore CBSE (10 + 2) Sacred Hearts Senior Secondary School, Indore CBSE (10)
#
# Jun 2020 - Jun 2024 CGPA: 8.78
#
# Jun 2019 - May 2020 Percentage: 85.2%
#
# Jun 2017 - May 2018 Percentage: 91.1%
#
# EXPERIENCE
#
# Robotics Process Automation Developer Champion | UiPath
#
# Oct 2022 - Present
#
# Skills: Robotics Process Automation, Automation Architecture, Process Design Responsible for team leadership and technical presentation. Develop in-demand RPA skills on campus by conducting online and offline workshops and Hack-a-bot hackathon.
#
# Business Intelligence Analyst | Muniversiti

# %%
# !pip install tiktoken
# Out:
# ...
#    ---------------------------------------- 0.0/785.8 kB ? eta -:--:--
#     --------------------------------------- 10.2/785.8 kB ? eta -:--:--
#    - ------------------------------------- 30.7/785.8 kB 325.1 kB/s eta 0:00:03
#    -- ------------------------------------ 41.0/785.8 kB 279.3 kB/s eta 0:00:03
#    ---- ---------------------------------- 92.2/785.8 kB 521.8 kB/s eta 0:00:02
#    -------- ----------------------------- 174.1/785.8 kB 871.5 kB/s eta 0:00:01
#    ---------- --------------------------- 225.3/785.8 kB 915.1 kB/s eta 0:00:01
#    ------------------ --------------------- 358.4/785.8 kB 1.2 MB/s eta 0:00:01
#    ------------------ --------------------- 358.4/785.8 kB 1.2 MB/s eta 0:00:01
#    ------------------- -------------------- 389.1/785.8 kB 1.1 MB/s eta 0:00:01
#    ------------------------ --------------- 481.3/785.8 kB 1.2 MB/s eta 0:00:01
#    -------------------------- ------------- 512.0/785.8 kB 1.1 MB/s eta 0:00:01
# ...

# %%
import openai
from langchain.embeddings.openai import OpenAIEmbeddings

os.environ["OPENAI_API_KEY"] = "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"
api_key = os.getenv("OPENAI_API_KEY")

embeddings = OpenAIEmbeddings(openai_api_key=api_key)

query_result = embeddings.embed_query("Hello world")
print(len(query_result))
# embeddings = OpenAIEmbeddings(model_kwargs="dimple")

len(query_result)
# Out:
# 1536
# 1536

# %%
query_result
# Out:
# [-0.004862199989200548,
#  0.004893690799325888,
#  -0.01636268938864811,
#  -0.024474752996844817,
#  -0.017320012624161617,
#  0.01253968939321275,
#  -0.019108697717332417,
#  0.009107178051034795,
#  -0.010215658665266043,
#  -0.026981431913634606,
#  0.022824628213283567,
#  0.010316429630196156,
#  -0.02345444627843549,
#  -0.006638288944585727,
#  0.00803648585016041,
#  0.0027428602255604737,
#  0.0250793787864255,
#  -0.012092518585581335,
#  0.012911282442807865,
#  0.013037246614631792,
#  -0.010517971560056384,
#  -0.0034828972903042984,
#  0.003977304778785007,
#  0.008603323226384227,
#  -0.02067064860507175,
#  -0.0018516668298368,
#  0.012231078895190884,
#  -0.019159084131120045,
#  0.030558802099976207,
#  -0.031012270510839147,
#  0.003586817289680817,
#  -0.00782234778251456,
#  -0.006002171879218422,
#  -0.017748290622098456,
#  0.00484330531686083,
#  -0.015669887840600364,
#  0.0013407265030588383,
#  -0.015581713944778445,
#  0.01953697571526926,
# ...

# %%
# !pip install pinecone-client
# Out:
# ...
#    ---------------------------------------- 0.0/179.4 kB ? eta -:--:--
#    ------ -------------------------------- 30.7/179.4 kB 660.6 kB/s eta 0:00:01
#    -------------------------------------- - 174.1/179.4 kB 2.1 MB/s eta 0:00:01
#    -------------------------------------- - 174.1/179.4 kB 2.1 MB/s eta 0:00:01
#    -------------------------------------- 179.4/179.4 kB 904.4 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/300.4 kB ? eta -:--:--
#    ------------------- -------------------- 143.4/300.4 kB 8.3 MB/s eta 0:00:01
#    ------------------------------------ --- 276.5/300.4 kB 3.4 MB/s eta 0:00:01
#    ---------------------------------------  297.0/300.4 kB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  297.0/300.4 kB 3.1 MB/s eta 0:00:01
#    ---------------------------------------- 300.4/300.4 kB 1.4 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/62.5 kB ? eta -:--:--
# ...

# %%
import pinecone
from langchain.vectorstores import Pinecone
#initialize pinecone
pinecone.init(
    api_key="07762e74-d415-471f-9854-9526bdcb21fe", #find at app.pinecone.io
    environment="gcp-starter" #next to api key in console
)

index_name = "langchain-demo"

index = Pinecone.from_documents(docs, embeddings, index_name=index_name)

# %%
def get_similar_docs(query, k=2, score=False):
    if score:
        similar_docs = index.similarity_search_with_score(query, k=k)
    else:
        similar_docs = index.similarity_search(query, k=k)
    return similar_docs

query = "Describe education of Dimple"
similar_docs = get_similar_docs(query, score=True)
similar_docs
# Out:
# [(Document(page_content='Indore, India |\n\nDIMPLE AGRAWAL agrawaldimple79@gmail.com |\n\n(+91)8989431813\n\nlinkedin.com/in/dimpleagrawal |\n\ngithub.com/dimple-agrawal | twitter.com/diwwwmple\n\nEDUCATION\n\nMedi-Caps University, Indore Bachelor of Technology in Computer Science and Engineering\n\nAcquired Cummins India Scholarship covering the complete undergraduate tuition fee.\n\nShree Krishna Public School, Indore CBSE (10 + 2) Sacred Hearts Senior Secondary School, Indore CBSE (10)\n\nJun 2020 - Jun 2024 CGPA: 8.78\n\nJun 2019 - May 2020 Percentage: 85.2%\n\nJun 2017 - May 2018 Percentage: 91.1%\n\nEXPERIENCE\n\nRobotics Process Automation Developer Champion | UiPath\n\nOct 2022 - Present\n\nSkills: Robotics Process Automation, Automation Architecture, Process Design Responsible for team leadership and technical presentation. Develop in-demand RPA skills on campus by conducting online and offline workshops and Hack-a-bot hackathon.\n\nBusiness Intelligence Analyst | Muniversit
# ...

# %%
from langchain.llms import OpenAI

model_name = "text-davinci-003"
# model_name = "gpt-3.5-turbo"
# model_name = "gpt-4"
llm = OpenAI(model_name=model_name)

# %%
from langchain.chains.question_answering import load_qa_chain
chain = load_qa_chain(llm, chain_type="stuff")

def get_answer(query):
    similar_docs = get_similar_docs(query)
    print(similar_docs)
    answer = chain.run(input_documents=similar_docs, question=query)
    return answer

query ="Describe experience of Dimple"
get_answer(query)
# Out:
# [Document(page_content='Indore, India |\n\nDIMPLE AGRAWAL agrawaldimple79@gmail.com |\n\n(+91)8989431813\n\nlinkedin.com/in/dimpleagrawal |\n\ngithub.com/dimple-agrawal | twitter.com/diwwwmple\n\nEDUCATION\n\nMedi-Caps University, Indore Bachelor of Technology in Computer Science and Engineering\n\nAcquired Cummins India Scholarship covering the complete undergraduate tuition fee.\n\nShree Krishna Public School, Indore CBSE (10 + 2) Sacred Hearts Senior Secondary School, Indore CBSE (10)\n\nJun 2020 - Jun 2024 CGPA: 8.78\n\nJun 2019 - May 2020 Percentage: 85.2%\n\nJun 2017 - May 2018 Percentage: 91.1%\n\nEXPERIENCE\n\nRobotics Process Automation Developer Champion | UiPath\n\nOct 2022 - Present\n\nSkills: Robotics Process Automation, Automation Architecture, Process Design Responsible for team leadership and technical presentation. Develop in-demand RPA skills on campus by conducting online and offline workshops and Hack-a-bot hackathon.\n\nBusiness Intelligence Analyst | Muniversiti
# ...

# %%
query = "how many pages are there in total?"
get_answer(query)
# Out:
# ' There are 17 pages in total.'
